# %% [markdown]
# <a href="https://colab.research.google.com/github/Umanggoel2/AirBnb-project/blob/main/Final_Capstone_Project_AirBnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name** -

# %% [markdown]
# ##### **Project Type**    - Exploratory Data Analysis
# ##### **Contribution**    - Individual
# ##### **Member Name -** Umang Goel

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ***Introduction of Airbnb:***
# * The San Francisco-based startup Airbnb was founded in 2007 when two hosts opened their residence to three visitors. Since then, the firm has expanded to over 4 million hosts and hosted over 1.5 billion guests in practically every nation.
# * Airbnb serves as an online accommodation marketplace that links customers searching for short-term lodging with those wishing to lease out their properties. Airbnb gives hosts a comparatively simple method to make a little money from their homes.
# * The basic premise of Airbnb is to connect locals with those who have extra space in their homes or apartments that they can rent out to tourists. With the security of knowing that a large firm will manage payments and provide other assistance, hosts utilizing the platform get to market their rentals to millions of individuals around the world.
#
# ***Purpose of EDA:***
# * The main goal of this analysis is to understand the pattern and to provide useful insights into Airbnb to improve its functionality and serviceability.
# * First data is to be explored and cleaned using different data-wrangling techniques. The missing or null values are to be handled carefully as they will create problems during data analysis and can affect statistics and computations. Duplicates and outliers are also dealt with in this cleaning process only as they can cause errors in data collection, data entry, or data merging and can lead to false analysis results.
# * After cleaning the data, the identification of different patterns and trends present inside the data can be done using various data visualization techniques. Various graphs and charts can be created to visualize the data, and record observations and insight which will be very useful for future analysis and decision-making related to Airbnb.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Link- https://github.com/Umanggoel2/AirBnb-project

# %% [markdown]
# #**Problem Statement** -

# %% [markdown]
# Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb has become a one-of-a-kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts') behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services, and much more. This dataset has around 49,000 observations in it with 16 columns and it is a mix of categorical and numeric values. Explore and analyze the data to discover key understandings.
#
# ***Objectives-***
# 1. Which neighbourhood group has the maximum number of reviews?
#
# 2. What is the average price for each room type available for booking?
#
# 3. Most reviewed room types per month in neighbourhood groups.
#
# 4. How does the availability of the room vary throughout neighbourhoods & room type?
#
# 5. What is the relation between the number of reviews and price for different room types?
#
# 6. What is the location of availability of rooms according to their given latitudes & longitudes?
#
# 7. The relation between average minimum nights with neighbourhood groups and room type.
#
# 8. The price distribution between different neighbourhood groups
#
# 9. The maximum number of hosts present in different neighbourhood groups
#
# 10. The top 10 hosts according to their listings.
#
# 11. The correlation between different variables.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# **Dataset Description**
#
# The airbnb dataset contains information on various attributes of reservations, such as their room type, price, minimum nights, last review date and many more. This dataset includes a total of 48895 instances, with 16 different attributes.

# %% [markdown]
# ###Importing the needed libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ###Dataset Loading:

# %%
path_name = "/content/Airbnb NYC 2019.csv"
airbnb_df = pd.read_csv (path_name)

# %% [markdown]
# Here, airbnb_df is a Pandas DataFrame object that contains the airbnb dataset.

# %% [markdown]
# ### Dataset First View:

# %%
# Displaying complete dataset by calling the name
airbnb_df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Shape of the data

# %%
# Using shape attribute of pandas
airbnb_df.shape
# Out:
# (48895, 16)

# %% [markdown]
# The **first value** of the tuple obtained will denote to the **number of rows** i.e. **(48895)**in the dataset whereas the **second value** will denote the **number of columns** i.e. **(16)** in the dataset.

# %% [markdown]
# ### Dataset information

# %%
# Details of all the columns present in the dataset
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# The dataset includes attribute-
#
# 1. id: (Unique id of listing of all the dataset)
# 2. name: (Name of the property)
# 3. host_id: (Unique id for each host in the dataset)
# 4. host_name: (Name of the host)
# 5. neighbourhood_group: (Name of the group in the city such as- Bronx, Brooklyn, Manhattan, Queens, Staten Island)
# 6. neighbourhood: (Specific name of the neighbour where the listing is located)
# 7. latitude: (Latitude of the location, continuous from 40.49979 to 40.90804)
# 8. longitude: (Latitude of the location, continuous from -74.24285 to -73.71299)
# 9. room_type: (Type of room such as- Entire home/apt, Private room, Shared room)
# 10. price: (Price of the stay per night in USD)
# 11. minimum_nights: (Minimum number of nights, that a guest will stay at the listing)
# 12. number_of_reviews: (Total number of reviews the property has recieved)
# 13. last_review: (Date of the last review recieved by the property)
# 14. reviews_per_month: (Average number of reviews property recieved per month)
# 15. calculated_host_listings_count: (Overall number of listing that host has on airbnb)
# 16. availability_365: (Number of days out of 365 days, the property is available for booking)

# %% [markdown]
# ### Data Cleaning

# %%
# Displaying rows of the dataset using head() function
# By default head() will display 5 rows
# T denotes the transpose of the table (rows becomes columns and columns becomes rows)
airbnb_df.head().T
# Out:
#                                                                  0  \
# id                                                            2539
# name                            Clean & quiet apt home by the park
# host_id                                                       2787
# host_name                                                     John
# neighbourhood_group                                       Brooklyn
# neighbourhood                                           Kensington
# latitude                                                  40.64749
# longitude                                                -73.97237
# room_type                                             Private room
# price                                                          149
# minimum_nights                                                   1
# number_of_reviews                                                9
# last_review                                             2018-10-19
# ...

# %%
# Basic information of the dataset using info() function
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# The info() function will display the total count of non-null values and the data types of different columns.

# %%
# Dropping the duplicate values of rows using drop_duplicates() function
airbnb_df = airbnb_df.drop_duplicates()
airbnb_df.count()  #count() function will count the number of rows after dropping duplicates
# Out:
# id                                48895
# name                              48879
# host_id                           48895
# host_name                         48874
# neighbourhood_group               48895
# neighbourhood                     48895
# latitude                          48895
# longitude                         48895
# room_type                         48895
# price                             48895
# minimum_nights                    48895
# number_of_reviews                 48895
# last_review                       38843
# reviews_per_month                 38843
# calculated_host_listings_count    48895
# availability_365                  48895
# dtype: int64

# %% [markdown]
# The number of rows before dropping duplicates and number of rows after dropping duplicates are same. Hence, there is not any duplicates in the dataset.

# %%
# Check for null values in each column
# isnull() function returns value
airbnb_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# The columns **name** & **host_name** have very few null values which can handled easily by replacing null values with some values.

# %% [markdown]
# ***Handling missing data***

# %%
# Filling missing values in name & host_name with "No name"
airbnb_df["name"].fillna ('no name', inplace = True)
airbnb_df["host_name"].fillna ("no name", inplace = True)
airbnb_df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Concating the columns (number_of_reviews, reviews_per_month and last_review) where number_of_reviews = 0 & reviews_per_month = 0
new_num_of_reviews_df = airbnb_df[airbnb_df ["number_of_reviews"] == 0]
new_reviews_df = airbnb_df[airbnb_df ["reviews_per_month"]==0]
new_df = pd.concat([new_num_of_reviews_df,new_reviews_df], axis = 0)
new_df [["number_of_reviews","reviews_per_month","last_review"]]
# Out:
#        number_of_reviews  reviews_per_month last_review
# 2                      0                NaN         NaN
# 19                     0                NaN         NaN
# 26                     0                NaN         NaN
# 36                     0                NaN         NaN
# 38                     0                NaN         NaN
# ...                  ...                ...         ...
# 48890                  0                NaN         NaN
# 48891                  0                NaN         NaN
# 48892                  0                NaN         NaN
# 48893                  0                NaN         NaN
# 48894                  0                NaN         NaN
#
# [10052 rows x 3 columns]

# %% [markdown]
# From the above table, we can see that there are 10052 rows where the **reviews_per_month** column has null values and **number_of_reviews** = 0. So, we can say that **reviews_per_month** = 0 when **number_of_reviews** = 0. The missing values of **reviews_per_month** can replaced by 0 as there is no reviews for such listing.

# %%
# Replacing all the null values in review_per_month column by 0
airbnb_df["reviews_per_month"] = airbnb_df["reviews_per_month"].replace(np.nan, value=0)
airbnb_df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# The **last_review** column can be dropped as it tell us about the last date of the review, but when **number_of_reviews** = 0 the value of **last_review** will always be 0 and it will not be required in the analysis

# %%
#Dropping last_review column using drop() function
airbnb_df = airbnb_df.drop(['last_review'], axis=1)
airbnb_df.head().T
# Out:
#                                                                  0  \
# id                                                            2539
# name                            Clean & quiet apt home by the park
# host_id                                                       2787
# host_name                                                     John
# neighbourhood_group                                       Brooklyn
# neighbourhood                                           Kensington
# latitude                                                  40.64749
# longitude                                                -73.97237
# room_type                                             Private room
# price                                                          149
# minimum_nights                                                   1
# number_of_reviews                                                9
# reviews_per_month                                             0.21
# ...

# %% [markdown]
# **Checking unique values for each variable**

# %%
#Check for unique id
airbnb_df ["id"].nunique()
# Out:
# 48895

# %%
#Check for unique host_id
airbnb_df ["host_id"].nunique()
# Out:
# 37457

# %%
#Check for unique neighbourhood_group
airbnb_df ["neighbourhood_group"].nunique()
# Out:
# 5

# %%
#Check for unique neighbourhood
airbnb_df ["neighbourhood"].nunique()
# Out:
# 221

# %%
#Check for unique room type
airbnb_df ["room_type"].nunique()
# Out:
# 3

# %% [markdown]
# ### Data Visualizing

# %% [markdown]
# 1. **Which neighbourhood group has the maximum number of reviews?**

# %%
#Grouping neighbourhood group column and number of reviews together and applying aggregation function for calculating maximum values
neighbour_group_review = airbnb_df.groupby ("neighbourhood_group")["number_of_reviews"].max()
neighbour_group_review
# Out:
# neighbourhood_group
# Bronx            321
# Brooklyn         488
# Manhattan        607
# Queens           629
# Staten Island    333
# Name: number_of_reviews, dtype: int64

# %%
#Creating Pie chart for visualizing the above data
mylabels = ["Bronx", "Brooklyn", "Manhattan", "Queens", "Staten Island" ]
myexplode = [0, 0, 0, 0.1, 0 ]

plt.pie (neighbour_group_review , labels = mylabels, autopct = "%1.1f%%", explode = myexplode)

plt.title ("Maximum number of reviews for different neighbourhood groups")

plt.show()

# %% [markdown]
# **Insights:**
#
# * The pie chart is the best suited chart for displaying one series of data.
# * From the graph, it is clearly shown that **Queens** (26.5%) and **Manhattan** (25.5%) neighbourhood groups are most popular among customers.
# * **Queens** has the highest percentage of reviews which made it the most popular location for travelers.

# %% [markdown]
# 2. **What is the average price for each room type available for booking?**

# %%
#Grouping Room type and price column together and applying aggregation function for calculating average or mean values
room_price_data = airbnb_df.groupby ("room_type", as_index=False)["price"].mean().round (2) #as_index = False will allow to check condition on same column not on index
room_price_data
# Out:
#          room_type   price
# 0  Entire home/apt  211.79
# 1     Private room   89.78
# 2      Shared room   70.13

# %%
#Creating Bar chart for visualizing the above data
ax = sns.barplot (data =room_price_data, x = "room_type", y = "price")

ax.set_title ("Average price for each room type")  #set_title () will help in setting the title of the chart

plt.show()

# %% [markdown]
# **Insights:**
# * A bar chart is good for visualizing the categorical data with the help of rectangular bars. They are best suited when we have to compare between different categories.
# * From the chart above, it is clearly visible that the **Entire home/apt** category of the room type is the most expensive category with an average price of 211.79 USD.
# * **Shared rooms** are the cheapest room category with the average price of 70.13 USD.

# %% [markdown]
# 3. **Most reviewed room type per month in neighbourhood groups.**

# %%
# Visualization of the data using strip plot
ax = sns.stripplot (x = "room_type", y = "reviews_per_month", hue = "neighbourhood_group", data = airbnb_df, dodge = True) #dodge is used for separating the strips for different hue
ax.set_title ("Most reviewed room type in each neighbourhood groups")
plt.show()

# %% [markdown]
# **Insights:**
#
# * Strip plots are best suited when we have to visualize the distribution of many categories in one-dimension. The values are plotted as a dots along a single axis, but dot with similar value can overlap each other.
#
# * **Manahattan** neighbourhood group have maximum reviews per month for **Private** room type.
#
# * **Staten Island** recieved lowest reviews for their **Shared** room type as compared to the other room type.

# %% [markdown]
# 4. **How does the availability of the room vary throughout neighbourhoods & room type?**

# %%
#Visualization using line plot
ax = sns.lineplot (x = "neighbourhood_group", y = "availability_365", hue = "room_type", data = airbnb_df)
ax.set_title ("Availability of the room throughout neighbourhoods & room type")
plt.show()

# %% [markdown]
# **Insights**
#
# * Line plots are usually used when the relationship or trends between two categories is to be plotted. It is a quick and simple manner to visualize the data by joining the series of points with a line. They are good when the ups and downs of the data are to be shown.
#
# * The **Private** room type for **Staten Island** are most available room type whereas the **Shared** room type for **Staten Island** is most busiest room type.

# %% [markdown]
# 5. **What is the relation between the number of reviews and price for different room types?**

# %%
# Visualization of the data using scatter plot
ax = sns.scatterplot (x = "number_of_reviews", y = "price", hue = "room_type", data = airbnb_df)
ax.set_title ("Relation between the number of reviews and price for different room types")
plt.show()

# %% [markdown]
# **Insights:**
#
# * Scatter plots are used to describe the pattern between two numeric variables. They are best suited to visualizing huge and complex data sets.
#
# * The **number of reviews** given by the customers decreases when the **price** of the room type is huge. Similarly, the **number of reviews**  increases when the **price** of the room gets decreased.
#
# * This trend shows that cheaper rooms have more guests as compared to the expensive rooms.

# %% [markdown]
# 6. **What is the location of availability of rooms according to their given latitudes & longitudes?**

# %%
# Visualization of the data using scatter plot
ax = sns.scatterplot (x = "longitude", y = "latitude", hue = "availability_365", data = airbnb_df)
ax.set_title ("Location of availability of the rooms")
plt.show()

# %% [markdown]
# **Insights:**
#
# * Scatter plots are used to describe the pattern between two numeric variables. They are best suited to visualizing huge and complex data sets.
#
# * From the chart, it is clearly visible that the center location of the city remains the busiest as the availability of the rooms as very less whereas the outer portion of the city remains mostly available throughout the year.

# %% [markdown]
# 7. **The relation between average minimum nights with neighbourhood groups and room type.**

# %%
#Grouping neighbourhood group column and minimum nights together and applying aggregation function for calculating mean values
neighbour_minimum_nights = airbnb_df.groupby (["neighbourhood_group", "room_type"], as_index = False)["minimum_nights"].mean().round (2)
neighbour_minimum_nights
# Out:
#    neighbourhood_group        room_type  minimum_nights
# 0                Bronx  Entire home/apt            5.96
# 1                Bronx     Private room            3.86
# 2                Bronx      Shared room            3.37
# 3             Brooklyn  Entire home/apt            6.53
# 4             Brooklyn     Private room            5.54
# 5             Brooklyn      Shared room            7.75
# 6            Manhattan  Entire home/apt           10.54
# 7            Manhattan     Private room            5.45
# 8            Manhattan      Shared room            6.77
# 9               Queens  Entire home/apt            5.37
# 10              Queens     Private room            5.12
# 11              Queens      Shared room            4.23
# 12       Staten Island  Entire home/apt            6.24
# 13       Staten Island     Private room            3.63
# 14       Staten Island      Shared room            2.33

# %%
# Visualization of the data
ax = sns.barplot (x = "neighbourhood_group", y = "minimum_nights", hue = "room_type", data = neighbour_minimum_nights )
ax.set_title ("Relation of average minimum nights with neighbourhood groups and room type ")
plt.show()

# %% [markdown]
# **Insights:**
#
# * A bar chart is good for visualizing the categorical data with the help of rectangular bars. They are best suited when we have to compare between different categories.
#
# * From the chart, it is clearly visible that **Manhattan** have maximum average minimum night (10.54) restriction policy for their **Entire home/Apt** room type as compared to other groups.
#
# * **Staten Island** have less average minimum night restriction policy (2.33) for their **Shared** room type as compared to other groups.

# %% [markdown]
# 8. **The price distribution between different neighbourhood groups**

# %% [markdown]
# **Dealing with outliers**

# %%
#Using describe() function for importing statistical details
airbnb_df [["price"]].describe().T.round(2)
# Out:
#          count    mean     std  min   25%    50%    75%      max
# price  48895.0  152.72  240.15  0.0  69.0  106.0  175.0  10000.0

# %%
#Calculating Inter Quartile Range (IQR)
#IQR = 75% - 25%
percentile_75 = airbnb_df['price'].quantile(0.75)

percentile_25 = airbnb_df['price'].quantile(0.25)

iqr = percentile_75 - percentile_25

print ("IQR = ", iqr)
# Out:
# IQR =  106.0

# %%
# Upper limit & lower limit of the data points
upper_limit = percentile_75 + 1.5*iqr
lower_limit = percentile_25 - 1.5*iqr
print ("Upper limit: ", upper_limit,"\n", "Lower Limit: ", lower_limit)
# Out:
# Upper limit:  334.0
#  Lower Limit:  -90.0

# %%
# Price should be less than or equal to upper limit
cond_1 = (airbnb_df['price'] <= upper_limit)
# Price should be greater than lower limit
cond_2 = (airbnb_df['price'] > lower_limit)
airbnb_df = airbnb_df[ cond_1 & cond_2]

# %%
# Visualization of the data
ax = sns.boxplot (x = "neighbourhood_group", y = "price", data = airbnb_df)
ax.set_title ("Price distribution between different neighbourhood groups")
plt.show()

# %% [markdown]
# **Insights:**
#
# * Box plot is used when the comparison in distributions needs to be performed between groups. The box plot represents the minimum, maximum, median, first quartile, and third quartile in the data set. It is also useful in comparing the distribution of data across data sets by drawing boxplots for each of them.
#
# * The median of the price in **Manhattan** group is maximum as compared to other groups. The median value is denoted by the center line of each boxplot.
#
# * The **Manhattan** group also has the maximum price denoted by the top line of the boxplot whereas **Staten Island** has the minimum price denoted by the bottom line of the boxplot.

# %% [markdown]
# 9. **The maximum number of hosts present in different neighbourhood groups.**

# %%
#Grouping neighbourhood group column and number of host together and applying aggregation function for calculating maximum values
neighbour_max_host = airbnb_df.groupby (["neighbourhood_group"], as_index = False)["calculated_host_listings_count"].max()
neighbour_max_host
# Out:
#   neighbourhood_group  calculated_host_listings_count
# 0               Bronx                              37
# 1            Brooklyn                             232
# 2           Manhattan                             327
# 3              Queens                             103
# 4       Staten Island                               8

# %%
#Visualization of the data
ax = sns.barplot (y = "neighbourhood_group", x = "calculated_host_listings_count", data = neighbour_max_host)
ax.set_title ("Maximum host present at different neighbourhood groups")
plt.show()

# %% [markdown]
# **Insights:**
#
# * A bar chart is good for visualizing the categorical data with the help of rectangular bars. They are best suited when we have to compare between different categories.
#
# * The chart shows that the maximum number of hosts are present in the **Manhattan** neighbourhood group i.e. 327
#
# * The minimum number of hosts are present in the **Staten Island** neighbourhood group i.e. 8

# %% [markdown]
# 10. **The top 10 properties according to their listings.**

# %%
#Top 10 hosts
top_host = airbnb_df["host_name"].value_counts()[:10]
top_host
# Out:
# Michael         417
# David           403
# Sonder (NYC)    327
# John            294
# Alex            279
# Blueground      232
# Sarah           227
# Daniel          226
# Jessica         205
# Maria           204
# Name: host_name, dtype: int64

# %%
#Visualization of the data
top_host.plot (kind = "bar")
plt.xlabel("Top 10 hosts")
plt.ylabel("Number of listing")
plt.title ("Top 10 host according to their listings")
plt.show()

# %% [markdown]
# **Insights:**
#
# * A bar chart is good for visualizing the categorical data with the help of rectangular bars. They are best suited when we have to compare between different categories.
#
# * The top 2 host according to the listings are **Michael** (417) & **David** (403).
#
# * The top 2 host mostly have their maximum properties in **Manahattan**, **Brooklyn** & **Queens** areas, which suggest that these areas are the mostly demanded and popular group.

# %% [markdown]
# 11. **The correlation between different variables.**

# %%
#Correlation of the data
corr_df = airbnb_df.corr().round (2)
#Visualization of the data
plt.figure (figsize = (8,6))
ax = sns.heatmap (corr_df, annot = True)
plt.show ()
# Out:
# <ipython-input-29-45784d5f1339>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_df = airbnb_df.corr().round (2)

# %% [markdown]
# **Insights:**
#
# * Using one variable on each axis, heatmaps are used to display relationships between two variables. You may determine if there are any patterns in the values for one or both variables by studying how the colors of the cells vary across each axis.
#
# * The **price** and **calculated host listings count** has a positive relation i.e. (0.17), which suggests that as the number of listing increases, the price may also increase.
#
# * The **number of reviews** and **reviews per month** has moderate postive relation i.e. (0.59).
#
# * The **minimum nights** and **reviews per month** have a negative correlation i.e. (-0.13), which suggests that if minimum nights increase, then reviews per month decrease.

# %% [markdown]
# # ***Conclusion***

# %% [markdown]
# *  **Queens** and **Manhattan** have the highest percentage of reviews which made them the most popular location for travelers. This also suggests that purchasing more and more properties in these areas and renting them to tourists will be more beneficial in terms of money as customers usually prefer to visit these groups.
#
# * The **Entire home/apt** category of the room type is the most expensive category with an average price of 211.79 USD whereas the **Shared rooms** are the cheapest room category with an average price of 70.13 USD. Also, the **number of reviews** given by the customers decreases when the **price** of the room type is large, this suggests that people usually prefer to stay at the location where the price is less.
#
# * The center location of the city remains the busiest as the availability of the rooms is very low whereas the outer portion of the city remains mostly available throughout the year. This suggests that the heart of New York City lies at the center portion, which is mostly **Manhattan**, **Brooklyn** and **Queens** neighbourhood groups. The top 2 host mostly have their properties in these neighbourhood groups only.
#
# * The maximum number of hosts are present in the **Manhattan** neighbourhood group i.e. 327. This suggests that **Manhattan** is the most popular neighbourhood group in New York City. So, the lifestyle and various local tourist place in Manhattan makes it best suitable for traveling in the city.
#
# * **Staten Island** is the least preferred neighbourhood group in the city as per the reviews and price. When tourists travel to such places, they prefer to invest in **Shared** room type as compared to **Private** or **Entire home/Apt**.
#
# * According to the analysis, Airbnb hosts face tough competition, with a small number of hosts controlling a significant portion of the market. To stand out from the competition, hosts might want to think about purchasing property in places where there are comparatively fewer listings.

# %% [markdown]
# # **Thanks !**
